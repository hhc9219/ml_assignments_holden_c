# %% [markdown]
# The following additional libraries are needed to run this
# notebook. Note that running on Colab is experimental, please report a Github
# issue if you have any problem.

# %%
# !pip install d2l==1.0.3
# Out:
# Collecting d2l==1.0.3
#   Obtaining dependency information for d2l==1.0.3 from https://files.pythonhosted.org/packages/8b/39/418ef003ed7ec0f2a071e24ec3f58c7b1f179ef44bec5224dcca276876e3/d2l-1.0.3-py3-none-any.whl.metadata
#   Using cached d2l-1.0.3-py3-none-any.whl.metadata (556 bytes)
# Collecting jupyter==1.0.0 (from d2l==1.0.3)
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: numpy==1.23.5 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from d2l==1.0.3) (1.23.5)
# Collecting matplotlib==3.7.2 (from d2l==1.0.3)
#   Obtaining dependency information for matplotlib==3.7.2 from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
#   Using cached matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from d2l==1.0.3) (0.1.6)
# Requirement already satisfied: requests==2.31.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from d2l==1.0.3) (2.31.0)
# Collecting pandas==2.0.3 (from d2l==1.0.3)
#   Obtaining dependency information for pandas==2.0.3 from https://files.pythonhosted.org/packages/9e/71/756a1be6bee0209d8c0d8c5e3b9fc72c00373f384a4017095ec404aec3ad/pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: scipy==1.10.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from d2l==1.0.3) (1.10.1)
# Collecting notebook (from jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for notebook from https://files.pythonhosted.org/packages/09/ab/332eaee7872d3883cf3a2cc6a2b2b1e36a566f16fa432c89204a5bd486e6/notebook-7.1.1-py3-none-any.whl.metadata
#   Using cached notebook-7.1.1-py3-none-any.whl.metadata (10 kB)
# Collecting qtconsole (from jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for qtconsole from https://files.pythonhosted.org/packages/d5/21/0887c50fa5bca7bfde29f65999a6ac234617f2a007b6b387aa4dc0ca36a8/qtconsole-5.5.1-py3-none-any.whl.metadata
#   Using cached qtconsole-5.5.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jupyter-console (from jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyter-console from https://files.pythonhosted.org/packages/ca/77/71d78d58f15c22db16328a476426f7ac4a60d3a5a7ba3b9627ee2f7903d4/jupyter_console-6.6.3-py3-none-any.whl.metadata
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for nbconvert from https://files.pythonhosted.org/packages/dc/6f/2c4e3dafb36dff2c98a170c1d61275f2e2d6bfd0f07d25771c1c18a6a529/nbconvert-7.16.1-py3-none-any.whl.metadata
#   Using cached nbconvert-7.16.1-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: ipykernel in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter==1.0.0->d2l==1.0.3) (6.29.3)
# Collecting ipywidgets (from jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for ipywidgets from https://files.pythonhosted.org/packages/70/1a/7edeedb1c089d63ccd8bd5c0612334774e90cf9337de9fe6c82d90081791/ipywidgets-8.1.2-py3-none-any.whl.metadata
#   Using cached ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib==3.7.2->d2l==1.0.3)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/ca/2a/d197a412ec474391ee878b1218cf2fe9c6e963903755887fc5654c06636a/contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib==3.7.2->d2l==1.0.3) (2.8.2)
# Requirement already satisfied: traitlets in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from matplotlib-inline==0.1.6->d2l==1.0.3) (5.14.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from pandas==2.0.3->d2l==1.0.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from pandas==2.0.3->d2l==1.0.3) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from requests==2.31.0->d2l==1.0.3) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l==1.0.3) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (8.22.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.7.1)
# Requirement already satisfied: nest-asyncio in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (1.6.0)
# Requirement already satisfied: psutil in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipykernel->jupyter==1.0.0->d2l==1.0.3) (6.4)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l==1.0.3) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->d2l==1.0.3) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l==1.0.3) (3.0.43)
# Requirement already satisfied: pygments in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-console->jupyter==1.0.0->d2l==1.0.3) (2.17.2)
# Collecting beautifulsoup4 (from nbconvert->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for beautifulsoup4 from https://files.pythonhosted.org/packages/b1/fe/e8c672695b37eecc5cbf43e1d0638d88d66ba3a44c4d321c796f4e59167f/beautifulsoup4-4.12.3-py3-none-any.whl.metadata
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (3.1.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (3.0.2)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for nbclient>=0.5.0 from https://files.pythonhosted.org/packages/6b/3a/607149974149f847125c38a62b9ea2b8267eb74823bbf8d8c54ae0212a00/nbclient-0.9.0-py3-none-any.whl.metadata
#   Using cached nbclient-0.9.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for nbformat>=5.7 from https://files.pythonhosted.org/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl.metadata
#   Using cached nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->d2l==1.0.3) (1.2.1)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyter-server<3,>=2.4.0 from https://files.pythonhosted.org/packages/25/d6/6ee093c967d11144aeb1b0b4952d30e51da8eb2737837ab612084c783a58/jupyter_server-2.12.5-py3-none-any.whl.metadata
#   Using cached jupyter_server-2.12.5-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyterlab-server<3,>=2.22.1 from https://files.pythonhosted.org/packages/ab/ac/a19c579bb8ab2a2aefcf47cd3787683e6e136378d7ab2602be3b8e628030/jupyterlab_server-2.25.3-py3-none-any.whl.metadata
#   Using cached jupyterlab_server-2.25.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.2,>=4.1.1 (from notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyterlab<4.2,>=4.1.1 from https://files.pythonhosted.org/packages/73/85/00afa8fcb102f8480790861277d58d624f46968baad4f43fb4e15e696772/jupyterlab-4.1.2-py3-none-any.whl.metadata
#   Using cached jupyterlab-4.1.2-py3-none-any.whl.metadata (15 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for notebook-shim<0.3,>=0.2 from https://files.pythonhosted.org/packages/f9/33/bd5b9137445ea4b680023eb0469b2bb969d61303dedb2aac6560ff3d14a1/notebook_shim-0.2.4-py3-none-any.whl.metadata
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from qtconsole->jupyter==1.0.0->d2l==1.0.3) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->d2l==1.0.3) (0.5.1)
# Requirement already satisfied: decorator in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.6.3)
# Requirement already satisfied: colorama in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l==1.0.3) (4.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l==1.0.3) (306)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for anyio>=3.1.0 from https://files.pythonhosted.org/packages/14/fd/2f20c40b45e4fb4324834aea24bd4afdf1143390242c0b33774da0e2e34f/anyio-4.3.0-py3-none-any.whl.metadata
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for argon2-cffi from https://files.pythonhosted.org/packages/a4/6a/e8a041599e78b6b3752da48000b14c8d1e8a04ded09c88c714ba047f34f5/argon2_cffi-23.1.0-py3-none-any.whl.metadata
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyter-events>=0.9.0 from https://files.pythonhosted.org/packages/e3/55/0c1aa72f4317e826a471dc4adc3036acd11d496ded68c4bbac2a88551519/jupyter_events-0.9.0-py3-none-any.whl.metadata
#   Using cached jupyter_events-0.9.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyter-server-terminals from https://files.pythonhosted.org/packages/7c/ec/ebb52454525e1d346bfa2ea91b3dcda3b92687bb73b2c25a6d621d9eeaf1/jupyter_server_terminals-0.5.2-py3-none-any.whl.metadata
#   Using cached jupyter_server_terminals-0.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: overrides in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (7.7.0)
# Requirement already satisfied: prometheus-client in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.20.0)
# Requirement already satisfied: pywinpty in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.18.0)
# Requirement already satisfied: websocket-client in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.4)
# Collecting httpx>=0.25.0 (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for httpx>=0.25.0 from https://files.pythonhosted.org/packages/41/7b/ddacf6dcebb42466abd03f368782142baa82e08fc0c1f8eaa05b4bae87d5/httpx-0.27.0-py3-none-any.whl.metadata
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jupyter-lsp>=2.0.0 from https://files.pythonhosted.org/packages/d0/7b/9307b18c5e7ee46651acef8f436eadfd61a34b6c87ecf76ad305981badb2/jupyter_lsp-2.2.3-py3-none-any.whl.metadata
#   Using cached jupyter_lsp-2.2.3-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: babel>=2.10 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.9.17)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jsonschema>=4.18.0 from https://files.pythonhosted.org/packages/39/9d/b035d024c62c85f2e2d4806a59ca7b8520307f34e0932fbc8cc75fe7b2d9/jsonschema-4.21.1-py3-none-any.whl.metadata
#   Using cached jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: fastjsonschema in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.19.1)
# Requirement already satisfied: wcwidth in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l==1.0.3) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l==1.0.3) (2.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (1.3.1)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/2c/93/13f25f2f78646bab97aee7680821e30bd85b2ff0fc45d5fdf5393b79716d/httpcore-1.0.4-py3-none-any.whl.metadata
#   Using cached httpcore-1.0.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (23.2.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/ee/07/44bd408781594c4d0a027666ef27fab1e441b109dc3b76b4f836f8fd04fe/jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (0.18.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (0.1.1)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for argon2-cffi-bindings from https://files.pythonhosted.org/packages/37/2c/e34e47c7dee97ba6f01a6203e0383e15b60fb85d78ac9a15cd066f6fe28b/argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l==1.0.3) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (1.5.1)
# Collecting isoduration (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2.4)
# Requirement already satisfied: uri-template in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (1.13)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for cffi>=1.0.1 from https://files.pythonhosted.org/packages/5a/c7/694814b3757878b29da39bc2f0cf9d20295f4c1e0a0bde7971708d5f23f8/cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: pycparser in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l==1.0.3) (2.21)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3)
#   Obtaining dependency information for arrow>=0.15.0 from https://files.pythonhosted.org/packages/f8/ed/e97229a566617f2ae958a6b13e7cc0f585470eac730a73e9e82c32a3cdd2/arrow-1.3.0-py3-none-any.whl.metadata
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\holde\src\python\ml_assignments_holden_c\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l==1.0.3) (2.8.19.20240106)
# Using cached d2l-1.0.3-py3-none-any.whl (111 kB)
# Using cached matplotlib-3.7.2-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
# Using cached ipywidgets-8.1.2-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached nbconvert-7.16.1-py3-none-any.whl (257 kB)
# Using cached notebook-7.1.1-py3-none-any.whl (5.0 MB)
# Using cached qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Using cached jupyter_server-2.12.5-py3-none-any.whl (380 kB)
# Using cached jupyterlab-4.1.2-py3-none-any.whl (11.4 MB)
# Using cached jupyterlab_server-2.25.3-py3-none-any.whl (58 kB)
# Using cached nbclient-0.9.0-py3-none-any.whl (24 kB)
# Using cached nbformat-5.9.2-py3-none-any.whl (77 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.4-py3-none-any.whl (77 kB)
# Using cached jsonschema-4.21.1-py3-none-any.whl (85 kB)
# Using cached jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.3-py3-none-any.whl (69 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached jupyter_server_terminals-0.5.2-py3-none-any.whl (13 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Installing collected packages: httpcore, contourpy, cffi, beautifulsoup4, anyio, pandas, matplotlib, jupyter-server-terminals, jsonschema-specifications, httpx, arrow, argon2-cffi-bindings, jsonschema, isoduration, argon2-cffi, nbformat, ipywidgets, qtconsole, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, d2l
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\holde\\src\\python\\ml_assignments_holden_c\\venv\\Lib\\site-packages\\pandas\\tests\\frame\\methods\\test_to_csv.py'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Linear Regression Implementation from Scratch
# :label:`sec_linear_scratch`
#
# We are now ready to work through
# a fully functioning implementation
# of linear regression.
# In this section,
# (**we will implement the entire method from scratch,
# including (i) the model; (ii) the loss function;
# (iii) a minibatch stochastic gradient descent optimizer;
# and (iv) the training function
# that stitches all of these pieces together.**)
# Finally, we will run our synthetic data generator
# from :numref:`sec_synthetic-regression-data`
# and apply our model
# on the resulting dataset.
# While modern deep learning frameworks
# can automate nearly all of this work,
# implementing things from scratch is the only way
# to make sure that you really know what you are doing.
# Moreover, when it is time to customize models,
# defining our own layers or loss functions,
# understanding how things work under the hood will prove handy.
# In this section, we will rely only
# on tensors and automatic differentiation.
# Later, we will introduce a more concise implementation,
# taking advantage of the bells and whistles of deep learning frameworks
# while retaining the structure of what follows below.

# %%
# %matplotlib inline
import torch
from d2l import torch as d2l

# %% [markdown]
# ## Defining the Model
#
# [**Before we can begin optimizing our model's parameters**] by minibatch SGD,
# (**we need to have some parameters in the first place.**)
# In the following we initialize weights by drawing
# random numbers from a normal distribution with mean 0
# and a standard deviation of 0.01.
# The magic number 0.01 often works well in practice,
# but you can specify a different value
# through the argument `sigma`.
# Moreover we set the bias to 0.
# Note that for object-oriented design
# we add the code to the `__init__` method of a subclass of `d2l.Module` (introduced in :numref:`subsec_oo-design-models`).

# %%
class LinearRegressionScratch(d2l.Module):  #@save
    """The linear regression model implemented from scratch."""
    def __init__(self, num_inputs, lr, sigma=0.01):
        super().__init__()
        self.save_hyperparameters()
        self.w = torch.normal(0, sigma, (num_inputs, 1), requires_grad=True)
        self.b = torch.zeros(1, requires_grad=True)

# %% [markdown]
# Next we must [**define our model,
# relating its input and parameters to its output.**]
# Using the same notation as :eqref:`eq_linreg-y-vec`
# for our linear model we simply take the matrix--vector product
# of the input features $\mathbf{X}$
# and the model weights $\mathbf{w}$,
# and add the offset $b$ to each example.
# The product $\mathbf{Xw}$ is a vector and $b$ is a scalar.
# Because of the broadcasting mechanism
# (see :numref:`subsec_broadcasting`),
# when we add a vector and a scalar,
# the scalar is added to each component of the vector.
# The resulting `forward` method
# is registered in the `LinearRegressionScratch` class
# via `add_to_class` (introduced in :numref:`oo-design-utilities`).

# %%
@d2l.add_to_class(LinearRegressionScratch)  #@save
def forward(self, X):
    return torch.matmul(X, self.w) + self.b

# %% [markdown]
# ## Defining the Loss Function
#
# Since [**updating our model requires taking
# the gradient of our loss function,**]
# we ought to (**define the loss function first.**)
# Here we use the squared loss function
# in :eqref:`eq_mse`.
# In the implementation, we need to transform the true value `y`
# into the predicted value's shape `y_hat`.
# The result returned by the following method
# will also have the same shape as `y_hat`.
# We also return the averaged loss value
# among all examples in the minibatch.

# %%
@d2l.add_to_class(LinearRegressionScratch)  #@save
def loss(self, y_hat, y):
    l = (y_hat - y) ** 2 / 2
    return l.mean()

# %% [markdown]
# ## Defining the Optimization Algorithm
#
# As discussed in :numref:`sec_linear_regression`,
# linear regression has a closed-form solution.
# However, our goal here is to illustrate
# how to train more general neural networks,
# and that requires that we teach you
# how to use minibatch SGD.
# Hence we will take this opportunity
# to introduce your first working example of SGD.
# At each step, using a minibatch
# randomly drawn from our dataset,
# we estimate the gradient of the loss
# with respect to the parameters.
# Next, we update the parameters
# in the direction that may reduce the loss.
#
# The following code applies the update,
# given a set of parameters, a learning rate `lr`.
# Since our loss is computed as an average over the minibatch,
# we do not need to adjust the learning rate against the batch size.
# In later chapters we will investigate
# how learning rates should be adjusted
# for very large minibatches as they arise
# in distributed large-scale learning.
# For now, we can ignore this dependency.

# %% [markdown]
# We define our `SGD` class,
# a subclass of `d2l.HyperParameters` (introduced in :numref:`oo-design-utilities`),
# to have a similar API
# as the built-in SGD optimizer.
# We update the parameters in the `step` method.
# The `zero_grad` method sets all gradients to 0,
# which must be run before a backpropagation step.

# %%
class SGD(d2l.HyperParameters):  #@save
    """Minibatch stochastic gradient descent."""
    def __init__(self, params, lr):
        self.save_hyperparameters()

    def step(self):
        for param in self.params:
            param -= self.lr * param.grad

    def zero_grad(self):
        for param in self.params:
            if param.grad is not None:
                param.grad.zero_()

# %% [markdown]
# We next define the `configure_optimizers` method, which returns an instance of the `SGD` class.

# %%
@d2l.add_to_class(LinearRegressionScratch)  #@save
def configure_optimizers(self):
    return SGD([self.w, self.b], self.lr)

# %% [markdown]
# ## Training
#
# Now that we have all of the parts in place
# (parameters, loss function, model, and optimizer),
# we are ready to [**implement the main training loop.**]
# It is crucial that you understand this code fully
# since you will employ similar training loops
# for every other deep learning model
# covered in this book.
# In each *epoch*, we iterate through
# the entire training dataset,
# passing once through every example
# (assuming that the number of examples
# is divisible by the batch size).
# In each *iteration*, we grab a minibatch of training examples,
# and compute its loss through the model's `training_step` method.
# Then we compute the gradients with respect to each parameter.
# Finally, we will call the optimization algorithm
# to update the model parameters.
# In summary, we will execute the following loop:
#
# * Initialize parameters $(\mathbf{w}, b)$
# * Repeat until done
#     * Compute gradient $\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#     * Update parameters $(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#
# Recall that the synthetic regression dataset
# that we generated in :numref:``sec_synthetic-regression-data``
# does not provide a validation dataset.
# In most cases, however,
# we will want a validation dataset
# to measure our model quality.
# Here we pass the validation dataloader
# once in each epoch to measure the model performance.
# Following our object-oriented design,
# the `prepare_batch` and `fit_epoch` methods
# are registered in the `d2l.Trainer` class
# (introduced in :numref:`oo-design-training`).

# %%
@d2l.add_to_class(d2l.Trainer)  #@save
def prepare_batch(self, batch):
    return batch

# %%
@d2l.add_to_class(d2l.Trainer)  #@save
def fit_epoch(self):
    self.model.train()
    for batch in self.train_dataloader:
        loss = self.model.training_step(self.prepare_batch(batch))
        self.optim.zero_grad()
        with torch.no_grad():
            loss.backward()
            if self.gradient_clip_val > 0:  # To be discussed later
                self.clip_gradients(self.gradient_clip_val, self.model)
            self.optim.step()
        self.train_batch_idx += 1
    if self.val_dataloader is None:
        return
    self.model.eval()
    for batch in self.val_dataloader:
        with torch.no_grad():
            self.model.validation_step(self.prepare_batch(batch))
        self.val_batch_idx += 1

# %% [markdown]
# We are almost ready to train the model,
# but first we need some training data.
# Here we use the `SyntheticRegressionData` class
# and pass in some ground truth parameters.
# Then we train our model with
# the learning rate `lr=0.03`
# and set `max_epochs=3`.
# Note that in general, both the number of epochs
# and the learning rate are hyperparameters.
# In general, setting hyperparameters is tricky
# and we will usually want to use a three-way split,
# one set for training,
# a second for hyperparameter selection,
# and the third reserved for the final evaluation.
# We elide these details for now but will revise them
# later.

# %%
model = LinearRegressionScratch(2, lr=0.03)
data = d2l.SyntheticRegressionData(w=torch.tensor([2, -3.4]), b=4.2)
trainer = d2l.Trainer(max_epochs=3)
trainer.fit(model, data)

# %% [markdown]
# Because we synthesized the dataset ourselves,
# we know precisely what the true parameters are.
# Thus, we can [**evaluate our success in training
# by comparing the true parameters
# with those that we learned**] through our training loop.
# Indeed they turn out to be very close to each other.

# %%
with torch.no_grad():
    print(f'error in estimating w: {data.w - model.w.reshape(data.w.shape)}')
    print(f'error in estimating b: {data.b - model.b}')
# Out:
# error in estimating w: tensor([ 0.0854, -0.1690])
# error in estimating b: tensor([0.2142])

# %% [markdown]
# We should not take the ability to exactly recover
# the ground truth parameters for granted.
# In general, for deep models unique solutions
# for the parameters do not exist,
# and even for linear models,
# exactly recovering the parameters
# is only possible when no feature
# is linearly dependent on the others.
# However, in machine learning,
# we are often less concerned
# with recovering true underlying parameters,
# but rather with parameters
# that lead to highly accurate prediction :cite:`Vapnik.1992`.
# Fortunately, even on difficult optimization problems,
# stochastic gradient descent can often find remarkably good solutions,
# owing partly to the fact that, for deep networks,
# there exist many configurations of the parameters
# that lead to highly accurate prediction.
#
#
# ## Summary
#
# In this section, we took a significant step
# towards designing deep learning systems
# by implementing a fully functional
# neural network model and training loop.
# In this process, we built a data loader,
# a model, a loss function, an optimization procedure,
# and a visualization and monitoring tool.
# We did this by composing a Python object
# that contains all relevant components for training a model.
# While this is not yet a professional-grade implementation
# it is perfectly functional and code like this
# could already help you to solve small problems quickly.
# In the coming sections, we will see how to do this
# both *more concisely* (avoiding boilerplate code)
# and *more efficiently* (using our GPUs to their full potential).
#
#
#
# ## Exercises
#
# 1. What would happen if we were to initialize the weights to zero. Would the algorithm still work? What if we
#    initialized the parameters with variance $1000$ rather than $0.01$?
# 1. Assume that you are [Georg Simon Ohm](https://en.wikipedia.org/wiki/Georg_Ohm) trying to come up
#    with a model for resistance that relates voltage and current. Can you use automatic
#    differentiation to learn the parameters of your model?
# 1. Can you use [Planck's Law](https://en.wikipedia.org/wiki/Planck%27s_law) to determine the temperature of an object
#    using spectral energy density? For reference, the spectral density $B$ of radiation emanating from a black body is
#    $B(\lambda, T) = \frac{2 hc^2}{\lambda^5} \cdot \left(\exp \frac{h c}{\lambda k T} - 1\right)^{-1}$. Here
#    $\lambda$ is the wavelength, $T$ is the temperature, $c$ is the speed of light, $h$ is Planck's constant, and $k$ is the
#    Boltzmann constant. You measure the energy for different wavelengths $\lambda$ and you now need to fit the spectral
#    density curve to Planck's law.
# 1. What are the problems you might encounter if you wanted to compute the second derivatives of the loss? How would
#    you fix them?
# 1. Why is the `reshape` method needed in the `loss` function?
# 1. Experiment using different learning rates to find out how quickly the loss function value drops. Can you reduce the
#    error by increasing the number of epochs of training?
# 1. If the number of examples cannot be divided by the batch size, what happens to `data_iter` at the end of an epoch?
# 1. Try implementing a different loss function, such as the absolute value loss `(y_hat - d2l.reshape(y, y_hat.shape)).abs().sum()`.
#     1. Check what happens for regular data.
#     1. Check whether there is a difference in behavior if you actively perturb some entries, such as $y_5 = 10000$, of $\mathbf{y}$.
#     1. Can you think of a cheap solution for combining the best aspects of squared loss and absolute value loss?
#        Hint: how can you avoid really large gradient values?
# 1. Why do we need to reshuffle the dataset? Can you design a case where a maliciously constructed dataset would break the optimization algorithm otherwise?

# %% [markdown]
# [Discussions](https://discuss.d2l.ai/t/43)
